# %%
import pandas as pd
import requests
# import wget
import zipfile
from io import BytesIO
import os
from typing import List
import shutil

# %%
DATA_DIR = "./data/"

# List of all files we get from unzipping
all_files = ['NONDERIV_TRANS.tsv',
 'NONDERIV_HOLDING.tsv',
 'OWNER_SIGNATURE.tsv',
 'REPORTINGOWNER.tsv',
 'DERIV_HOLDING.tsv',
 'insider_transactions_metadata.json',
 'insider_transactions_readme.htm',
 'DERIV_TRANS.tsv',
 'SUBMISSION.tsv',
 'FOOTNOTES.tsv'
]

# %%
pd.set_option("display.max_columns", 100)

# %%
def get_insider_data_quaterly(year: int, quarter: int, data_dir:str = DATA_DIR) -> str:
    """
    Returns the folder name where the data is unzipped
    """

    base_url = f'https://www.sec.gov/files/structureddata/data/insider-transactions-data-sets/{str(year)}q{str(quarter)}_form345.zip'
    retval = requests.get(url=base_url)

    file_name = base_url.split('/')[-1]
    folder_name = file_name.split('.')[0]
    full_path = data_dir + file_name

    # Download the zip file in the data_dir
    with open(full_path, 'wb') as output_file:
        output_file.write(retval.content)
    
    # Create folder to extract files
    os.makedirs(os.path.join(data_dir, folder_name))
    
    try:
        # Extract the zip-files
        with zipfile.ZipFile(f'{full_path}', 'r') as zip_ref:
            zip_ref.extractall(os.path.join(data_dir, folder_name))
    except zipfile.BadZipFile as e:
        os.unlink(full_path)
        shutil.rmtree(os.path.join(data_dir, folder_name))
        print(f"data doesn't exist for {year} : {quarter}" )
        return ""

    
    return folder_name

# %%
def get_insider_data_from_files(interested_folders: List[str], interested_files: List[str] = all_files, data_dir:str = DATA_DIR) -> dict:
    d_data = {f:pd.DataFrame() for f in interested_files}

    for folder in interested_folders:
        for file in interested_files:
            if os.path.isfile(data_dir + folder + "/" + file):
                tmp_df = pd.read_csv(data_dir + folder + "/" + file, sep='\t', low_memory=False)
                d_data[file] = pd.concat([d_data[file], tmp_df])

    return d_data

# %%
years = [2023]
quarters = [4]
interested_files = ['NONDERIV_TRANS.tsv', 'NONDERIV_HOLDING.tsv',]
lst_folders = []

for year in years:
    for quar in quarters:
        lst_folders.append(get_insider_data_quaterly(year=year, quarter=quar, data_dir=DATA_DIR))
# Out:
# data doesn't exist for 2023 : 4

# %%
lst_folders
# Out:
# [None]

# %%
all_data_dict = get_insider_data_from_files(interested_files=interested_files, interested_folders=lst_folders)
# Out:
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (7,13,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (7,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (13,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
all_data_dict['NONDERIV_TRANS.tsv']
# Out:
#            ACCESSION_NUMBER  NONDERIV_TRANS_SK  \
# 0      0001104659-21-045073              47618
# 1      0001104659-21-045074              33206
# 2      0001104659-21-045075              48937
# 3      0001104659-21-045076              51699
# 4      0000899243-21-014303              41168
# ...                     ...                ...
# 69769  0000886346-22-000077            6060986
# 69770  0001654954-22-004385            6060841
# 69771  0001562180-22-003046            6060299
# 69772  0000899243-22-013011            6060361
# 69773  0001209191-22-021876            6060181
#
#                                      SECURITY_TITLE SECURITY_TITLE_FN  \
# 0         Common stock, par value $0.0001 per share               NaN
# 1         Common stock, par value $0.0001 per share               NaN
# 2         Common stock, par value $0.0001 per share               NaN
# 3         Common stock, par value $0.0001 per share               NaN
# 4                                      Common Stock               NaN
# ...                                             ...               ...
# 69769                                  Common Stock               NaN
# 69770               Community Bancorp. Common Stock               NaN
# 69771                                  Common Stock               NaN
# 69772  Class I common shares of beneficial interest               NaN
# 69773                                  Common Stock               NaN
#
#         TRANS_DATE TRANS_DATE_FN DEEMED_EXECUTION_DATE  \
# 0      29-MAR-2021           NaN                   NaN
# 1      29-MAR-2021           NaN                   NaN
# 2      29-MAR-2021           NaN                   NaN
# 3      29-MAR-2021           NaN                   NaN
# 4      26-MAR-2021           NaN                   NaN
# ...            ...           ...                   ...
# 69769  31-MAR-2022           NaN                   NaN
# 69770  31-MAR-2022           NaN                   NaN
# 69771  31-MAR-2022           NaN                   NaN
# 69772  31-MAR-2022           NaN                   NaN
# 69773  30-MAR-2022           NaN                   NaN
#
#       DEEMED_EXECUTION_DATE_FN  TRANS_FORM_TYPE TRANS_CODE  \
# 0                          NaN                4          J
# 1                          NaN                4          J
# 2                          NaN                4          J
# 3                          NaN                4          J
# 4                          NaN                4          X
# ...                        ...              ...        ...
# 69769                      NaN                4          F
# 69770                      NaN                4          P
# 69771                      NaN                4          S
# 69772                      NaN                4          S
# 69773                      NaN                4          P
#
#       EQUITY_SWAP_INVOLVED EQUITY_SWAP_TRANS_CD_FN TRANS_TIMELINESS  \
# 0                        0                      F1              NaN
# 1                        0                      F1              NaN
# 2                        0                      F1              NaN
# 3                        0                      F1              NaN
# 4                        0                     NaN              NaN
# ...                    ...                     ...              ...
# 69769                    0                     NaN              NaN
# 69770                false                     NaN              NaN
# 69771                false                      F1              NaN
# 69772                    0                     NaN              NaN
# 69773                    0                     NaN              NaN
#
#       TRANS_TIMELINESS_FN  TRANS_SHARES TRANS_SHARES_FN  TRANS_PRICEPERSHARE  \
# 0                     NaN      31250.00             NaN                 0.00
# 1                     NaN      31250.00             NaN                 0.00
# 2                     NaN      31250.00             NaN                 0.00
# 3                     NaN      31250.00             NaN                 0.00
# 4                     NaN     884175.00             NaN                 0.01
# ...                   ...           ...             ...                  ...
# 69769                 NaN        660.00             NaN               195.31
# 69770                 NaN        250.00             NaN                22.75
# 69771                 NaN       4500.00             NaN                29.24
# 69772                 NaN     164466.47              F1                 9.12
# 69773                 NaN       4000.00             NaN                 2.70
#
#       TRANS_PRICEPERSHARE_FN TRANS_ACQUIRED_DISP_CD TRANS_ACQUIRED_DISP_CD_FN  \
# 0                         F1                      D                       NaN
# 1                         F1                      D                       NaN
# 2                         F1                      D                       NaN
# 3                         F1                      D                       NaN
# 4                        NaN                      A                       NaN
# ...                      ...                    ...                       ...
# 69769                    NaN                      D                       NaN
# 69770                    NaN                      A                       NaN
# 69771                     F2                      D                       NaN
# 69772                     F1                      D                       NaN
# 69773                    NaN                      A                       NaN
#
#        SHRS_OWND_FOLWNG_TRANS SHRS_OWND_FOLWNG_TRANS_FN  \
# 0                  5450001.00                       NaN
# 1                  5450001.00                       NaN
# 2                  5450001.00                       NaN
# 3                  5450001.00                       NaN
# 4                  2492342.00                       NaN
# ...                       ...                       ...
# 69769                32749.00                       NaN
# 69770                35434.00                       NaN
# 69771                26022.00                        F3
# 69772               211788.28                        F1
# 69773               224518.00                       NaN
#
#        VALU_OWND_FOLWNG_TRANS VALU_OWND_FOLWNG_TRANS_FN  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ...                       ...                       ...
# 69769                     NaN                       NaN
# 69770                     NaN                       NaN
# 69771                     NaN                       NaN
# 69772                     NaN                       NaN
# 69773                     NaN                       NaN
#
#       DIRECT_INDIRECT_OWNERSHIP DIRECT_INDIRECT_OWNERSHIP_FN  \
# 0                             D                           F2
# 1                             I                          NaN
# 2                             I                          NaN
# 3                             I                          NaN
# 4                             I                          NaN
# ...                         ...                          ...
# 69769                         D                          NaN
# 69770                         D                          NaN
# 69771                         D                          NaN
# 69772                         D                          NaN
# 69773                         D                          NaN
#
#                                      NATURE_OF_OWNERSHIP  \
# 0                                                    NaN
# 1                                                 See FN
# 2                                                 See FN
# 3                                                 See FN
# 4      By Pillar Pharmaceuticals 6, L.P.   See Footnotes
# ...                                                  ...
# 69769                                                NaN
# 69770                                                NaN
# 69771                                                NaN
# 69772                                                NaN
# 69773                                                NaN
#
#       NATURE_OF_OWNERSHIP_FN
# 0                        NaN
# 1                         F2
# 2                         F2
# 3                         F2
# 4                     F2, F3
# ...                      ...
# 69769                    NaN
# 69770                    NaN
# 69771                    NaN
# 69772                    NaN
# 69773                    NaN
#
# [394829 rows x 28 columns]

# %%
all_data_dict['NONDERIV_HOLDING.tsv']
# Out:
#            ACCESSION_NUMBER  NONDERIV_HOLDING_SK  \
# 0      0000899243-21-014303                12020
# 1      0000899243-21-014303                12021
# 2      0000899243-21-014294                17299
# 3      0001854475-21-000002                10067
# 4      0001082440-21-000006                39251
# ...                     ...                  ...
# 22336  0001185185-22-000385              2014944
# 22337  0000806279-22-000069              2014723
# 22338  0001290476-22-000014              2014869
# 22339  0001127602-22-010778              2014840
# 22340  0000313616-22-000105              2014880
#
#                                 SECURITY_TITLE SECURITY_TITLE_FN  \
# 0                                 Common Stock               NaN
# 1                                 Common Stock               NaN
# 2                         Class A Common Stock               NaN
# 3       Class A Common Stock, par value $0.001                F1
# 4                                 Common Stock               NaN
# ...                                        ...               ...
# 22336  Common Stock, $5.00 par value per share               NaN
# 22337                             Common Stock               NaN
# 22338                             Common Stock               NaN
# 22339                             Common Stock               NaN
# 22340                             Common Stock               NaN
#
#        TRANS_FORM_TYPE  TRANS_FORM_TYPE_FN  SHRS_OWND_FOLWNG_TRANS  \
# 0                  NaN                 NaN                386110.0
# 1                  NaN                 NaN                 26308.0
# 2                  NaN                 NaN               5750000.0
# 3                  NaN                 NaN                 16029.0
# 4                  NaN                 NaN                 53872.0
# ...                ...                 ...                     ...
# 22336              NaN                 NaN               1381227.0
# 22337              NaN                 NaN                  6037.0
# 22338              NaN                 NaN                   264.0
# 22339              NaN                 NaN                  2435.0
# 22340              NaN                 NaN                  5195.0
#
#       SHRS_OWND_FOLWNG_TRANS_FN  VALU_OWND_FOLWNG_TRANS  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                        F4, F3                     NaN
# 3                           NaN                     NaN
# 4                            F5                     NaN
# ...                         ...                     ...
# 22336                       NaN                     NaN
# 22337                       NaN                     NaN
# 22338                        F1                     NaN
# 22339                       NaN                     NaN
# 22340                       NaN                     NaN
#
#       VALU_OWND_FOLWNG_TRANS_FN DIRECT_INDIRECT_OWNERSHIP  \
# 0                           NaN                         I
# 1                           NaN                         I
# 2                           NaN                         I
# 3                           NaN                         D
# 4                           NaN                         D
# ...                         ...                       ...
# 22336                       NaN                         I
# 22337                       NaN                         I
# 22338                       NaN                         D
# 22339                       NaN                         I
# 22340                       NaN                         D
#
#       DIRECT_INDIRECT_OWNERSHIP_FN  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 22336                          NaN
# 22337                          NaN
# 22338                          NaN
# 22339                          NaN
# 22340                          NaN
#
#                                      NATURE_OF_OWNERSHIP  \
# 0                         By Abude Umari   See Footnotes
# 1                      By Youssef El Zein  See Footnotes
# 2                                          See Footnotes
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 22336  By the Article 6 Marital Trust, under the Jerr...
# 22337  Jack Giambalvo Motor Co profit sharing plan FB...
# 22338                                                NaN
# 22339                      Prft Shring/Saving Plan Trust
# 22340                                                NaN
#
#       NATURE_OF_OWNERSHIP_FN
# 0                 F5, F6, F2
# 1                         F2
# 2                     F4, F3
# 3                        NaN
# 4                        NaN
# ...                      ...
# 22336                    NaN
# 22337                    NaN
# 22338                    NaN
# 22339                    NaN
# 22340                    NaN
#
# [117310 rows x 14 columns]

# %%
def cleanup(data_dir:str = DATA_DIR) -> None:
    for filename in os.listdir(data_dir):
        file_path = os.path.join(data_dir, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))
    return

# %%
cleanup()

# %%
deriv_transactions = pd.read_csv('DERIV_TRANS.tsv', sep='\t')
print(deriv_transactions.info())
deriv_transactions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29457 entries, 0 to 29456
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ACCESSION_NUMBER              29457 non-null  object
#  1   DERIV_TRANS_SK                29457 non-null  int64
#  2   SECURITY_TITLE                29457 non-null  object
#  3   SECURITY_TITLE_FN             1970 non-null   object
#  4   CONV_EXERCISE_PRICE           14466 non-null  float64
#  5   CONV_EXERCISE_PRICE_FN        16987 non-null  object
#  6   TRANS_DATE                    29457 non-null  object
#  7   TRANS_DATE_FN                 275 non-null    object
#  8   DEEMED_EXECUTION_DATE         154 non-null    object
#  9   DEEMED_EXECUTION_DATE_FN      30 non-null     object
#  10  TRANS_FORM_TYPE               29457 non-null  int64
#  11  TRANS_CODE                    29457 non-null  object
#  12  EQUITY_SWAP_INVOLVED          29457 non-null  object
#  13  EQUITY_SWAP_TRANS_CD_FN       3272 non-null   object
#  14  TRANS_TIMELINESS              190 non-null    object
#  15  TRANS_TIMELINESS_FN           1 non-null      object
#  16  TRANS_SHARES                  29329 non-null  float64
#  17  TRANS_SHARES_FN               2791 non-null   object
#  18  TRANS_TOTAL_VALUE             128 non-null    float64
#  19  TRANS_TOTAL_VALUE_FN          26 non-null     object
#  20  TRANS_PRICEPERSHARE           26200 non-null  float64
#  21  TRANS_PRICEPERSHARE_FN        4226 non-null   object
#  22  TRANS_ACQUIRED_DISP_CD        29457 non-null  object
#  23  TRANS_ACQUIRED_DISP_CD_FN     0 non-null      float64
#  24  EXCERCISE_DATE                5032 non-null   object
#  25  EXCERCISE_DATE_FN             26060 non-null  object
#  26  EXPIRATION_DATE               12234 non-null  object
#  27  EXPIRATION_DATE_FN            17574 non-null  object
#  28  UNDLYNG_SEC_TITLE             29457 non-null  object
#  29  UNDLYNG_SEC_TITLE_FN          383 non-null    object
#  30  UNDLYNG_SEC_SHARES            29375 non-null  float64
#  31  UNDLYNG_SEC_SHARES_FN         807 non-null    object
#  32  UNDLYNG_SEC_VALUE             13 non-null     float64
#  33  UNDLYNG_SEC_VALUE_FN          8 non-null      object
#  34  SHRS_OWND_FOLWNG_TRANS        29375 non-null  float64
#  35  SHRS_OWND_FOLWNG_TRANS_FN     1758 non-null   object
#  36  VALU_OWND_FOLWNG_TRANS        82 non-null     float64
#  37  VALU_OWND_FOLWNG_TRANS_FN     10 non-null     object
#  38  DIRECT_INDIRECT_OWNERSHIP     29457 non-null  object
#  39  DIRECT_INDIRECT_OWNERSHIP_FN  395 non-null    object
#  40  NATURE_OF_OWNERSHIP           1664 non-null   object
#  41  NATURE_OF_OWNERSHIP_FN        1175 non-null   object
# dtypes: float64(9), int64(2), object(31)
# memory usage: 9.4+ MB
# None
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ACCESSION_NUMBER  DERIV_TRANS_SK                  SECURITY_TITLE  \
# 0  0000899243-23-016780         2413204  PUT Option (Obligation to Buy)
# 1  0000899243-23-016780         2413206  PUT Option (Obligation to Buy)
# 2  0000899243-23-016780         2413205  PUT Option (Obligation to Buy)
# 3  0000899243-23-016780         2413209  PUT Option (Obligation to Buy)
# 4  0000899243-23-016780         2413208  PUT Option (Obligation to Buy)
#
#   SECURITY_TITLE_FN  CONV_EXERCISE_PRICE CONV_EXERCISE_PRICE_FN   TRANS_DATE  \
# 0               NaN                  4.0                    NaN  28-JUN-2023
# 1               NaN                  3.5                    NaN  28-JUN-2023
# 2               NaN                  3.5                    NaN  28-JUN-2023
# 3               NaN                  4.0                    NaN  28-JUN-2023
# 4               NaN                  4.0                    NaN  28-JUN-2023
#
#   TRANS_DATE_FN DEEMED_EXECUTION_DATE DEEMED_EXECUTION_DATE_FN  \
# 0           NaN                   NaN                      NaN
# 1           NaN                   NaN                      NaN
# 2           NaN                   NaN                      NaN
# 3           NaN                   NaN                      NaN
# 4           NaN                   NaN                      NaN
#
#    TRANS_FORM_TYPE TRANS_CODE EQUITY_SWAP_INVOLVED EQUITY_SWAP_TRANS_CD_FN  \
# 0                4          X                    0                     NaN
# 1                4          X                    0                     NaN
# 2                4          X                    0                     NaN
# 3                4          X                    0                     NaN
# 4                4          X                    0                     NaN
#
#   TRANS_TIMELINESS TRANS_TIMELINESS_FN  TRANS_SHARES TRANS_SHARES_FN  \
# 0              NaN                 NaN       20700.0             NaN
# 1              NaN                 NaN       15300.0             NaN
# 2              NaN                 NaN       43900.0             NaN
# 3              NaN                 NaN      100000.0             NaN
# 4              NaN                 NaN       31400.0             NaN
#
#    TRANS_TOTAL_VALUE TRANS_TOTAL_VALUE_FN  TRANS_PRICEPERSHARE  \
# 0                NaN                  NaN                  0.0
# 1                NaN                  NaN                  0.0
# 2                NaN                  NaN                  0.0
# 3                NaN                  NaN                  0.0
# 4                NaN                  NaN                  0.0
#
#   TRANS_PRICEPERSHARE_FN TRANS_ACQUIRED_DISP_CD  TRANS_ACQUIRED_DISP_CD_FN  \
# 0                    NaN                      D                        NaN
# 1                    NaN                      D                        NaN
# 2                    NaN                      D                        NaN
# 3                    NaN                      D                        NaN
# 4                    NaN                      D                        NaN
#
#   EXCERCISE_DATE EXCERCISE_DATE_FN EXPIRATION_DATE EXPIRATION_DATE_FN  \
# 0    31-JAN-2023               NaN     19-JAN-2024                NaN
# 1    17-NOV-2022               NaN     19-JAN-2024                NaN
# 2    03-NOV-2022               NaN     19-JAN-2024                NaN
# 3    25-JAN-2023               NaN     19-JAN-2024                NaN
# 4    12-DEC-2022               NaN     19-JAN-2024                NaN
#
#   UNDLYNG_SEC_TITLE UNDLYNG_SEC_TITLE_FN  UNDLYNG_SEC_SHARES  \
# 0      Common Stock                  NaN             20700.0
# 1      Common Stock                  NaN             15300.0
# 2      Common Stock                  NaN             43900.0
# 3      Common Stock                  NaN            100000.0
# 4      Common Stock                  NaN             31400.0
#
#   UNDLYNG_SEC_SHARES_FN  UNDLYNG_SEC_VALUE UNDLYNG_SEC_VALUE_FN  \
# 0                   NaN                NaN                  NaN
# 1                   NaN                NaN                  NaN
# 2                   NaN                NaN                  NaN
# 3                   NaN                NaN                  NaN
# 4                   NaN                NaN                  NaN
#
#    SHRS_OWND_FOLWNG_TRANS SHRS_OWND_FOLWNG_TRANS_FN  VALU_OWND_FOLWNG_TRANS  \
# 0               1281100.0                       NaN                     NaN
# 1                102300.0                       NaN                     NaN
# 2               1237200.0                       NaN                     NaN
# 3                143600.0                       NaN                     NaN
# 4                243600.0                       NaN                     NaN
#
#   VALU_OWND_FOLWNG_TRANS_FN DIRECT_INDIRECT_OWNERSHIP  \
# 0                       NaN                         I
# 1                       NaN                         I
# 2                       NaN                         I
# 3                       NaN                         I
# 4                       NaN                         I
#
#   DIRECT_INDIRECT_OWNERSHIP_FN    NATURE_OF_OWNERSHIP NATURE_OF_OWNERSHIP_FN
# 0                          NaN  By Crescent River LLC                    NaN
# 1                          NaN   By Elstead 2020 GRAT                    NaN
# 2                          NaN  By Crescent River LLC                    NaN
# 3                          NaN  By Shiraz Capital LLC                    NaN
# 4                          NaN  By Shiraz Capital LLC                    NaN

# %%
non_deriv_transactions = pd.read_csv('NONDERIV_TRANS.tsv', sep='\t')
print(non_deriv_transactions.info())
non_deriv_transactions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68588 entries, 0 to 68587
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ACCESSION_NUMBER              68588 non-null  object
#  1   NONDERIV_TRANS_SK             68588 non-null  int64
#  2   SECURITY_TITLE                68588 non-null  object
#  3   SECURITY_TITLE_FN             2206 non-null   object
#  4   TRANS_DATE                    68588 non-null  object
#  5   TRANS_DATE_FN                 418 non-null    object
#  6   DEEMED_EXECUTION_DATE         689 non-null    object
#  7   DEEMED_EXECUTION_DATE_FN      53 non-null     object
#  8   TRANS_FORM_TYPE               68588 non-null  int64
#  9   TRANS_CODE                    68588 non-null  object
#  10  EQUITY_SWAP_INVOLVED          68588 non-null  object
#  11  EQUITY_SWAP_TRANS_CD_FN       16157 non-null  object
#  12  TRANS_TIMELINESS              672 non-null    object
#  13  TRANS_TIMELINESS_FN           14 non-null     object
#  14  TRANS_SHARES                  68588 non-null  float64
#  15  TRANS_SHARES_FN               21121 non-null  object
#  16  TRANS_PRICEPERSHARE           63765 non-null  float64
#  17  TRANS_PRICEPERSHARE_FN        20238 non-null  object
#  18  TRANS_ACQUIRED_DISP_CD        68588 non-null  object
#  19  TRANS_ACQUIRED_DISP_CD_FN     536 non-null    object
#  20  SHRS_OWND_FOLWNG_TRANS        68574 non-null  float64
#  21  SHRS_OWND_FOLWNG_TRANS_FN     9585 non-null   object
#  22  VALU_OWND_FOLWNG_TRANS        14 non-null     float64
#  23  VALU_OWND_FOLWNG_TRANS_FN     0 non-null      float64
#  24  DIRECT_INDIRECT_OWNERSHIP     68588 non-null  object
#  25  DIRECT_INDIRECT_OWNERSHIP_FN  1320 non-null   object
#  26  NATURE_OF_OWNERSHIP           10252 non-null  object
#  27  NATURE_OF_OWNERSHIP_FN        6409 non-null   object
# dtypes: float64(5), int64(2), object(21)
# memory usage: 14.7+ MB
# None
# /Users/kartikeysinha/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (7,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ACCESSION_NUMBER  NONDERIV_TRANS_SK SECURITY_TITLE SECURITY_TITLE_FN  \
# 0  0000899243-23-016780            6418208   COMMON STOCK               NaN
# 1  0000899243-23-016780            6418207   COMMON STOCK               NaN
# 2  0000899243-23-016780            6418206   COMMON STOCK               NaN
# 3  0000899243-23-016780            6418205   COMMON STOCK               NaN
# 4  0000899243-23-016780            6418204   COMMON STOCK               NaN
#
#     TRANS_DATE TRANS_DATE_FN DEEMED_EXECUTION_DATE DEEMED_EXECUTION_DATE_FN  \
# 0  28-JUN-2023           NaN                   NaN                      NaN
# 1  28-JUN-2023           NaN                   NaN                      NaN
# 2  28-JUN-2023           NaN                   NaN                      NaN
# 3  28-JUN-2023           NaN                   NaN                      NaN
# 4  28-JUN-2023           NaN                   NaN                      NaN
#
#    TRANS_FORM_TYPE TRANS_CODE EQUITY_SWAP_INVOLVED EQUITY_SWAP_TRANS_CD_FN  \
# 0                4          X                    0                     NaN
# 1                4          X                    0                     NaN
# 2                4          X                    0                     NaN
# 3                4          X                    0                     NaN
# 4                4          X                    0                     NaN
#
#   TRANS_TIMELINESS TRANS_TIMELINESS_FN  TRANS_SHARES TRANS_SHARES_FN  \
# 0              NaN                 NaN      131400.0             NaN
# 1              NaN                 NaN       24800.0             NaN
# 2              NaN                 NaN       15300.0             NaN
# 3              NaN                 NaN       43900.0             NaN
# 4              NaN                 NaN       20700.0             NaN
#
#    TRANS_PRICEPERSHARE TRANS_PRICEPERSHARE_FN TRANS_ACQUIRED_DISP_CD  \
# 0                  4.0                    NaN                      A
# 1                  4.0                    NaN                      A
# 2                  3.5                    NaN                      A
# 3                  3.5                    NaN                      A
# 4                  4.0                    NaN                      A
#
#   TRANS_ACQUIRED_DISP_CD_FN  SHRS_OWND_FOLWNG_TRANS SHRS_OWND_FOLWNG_TRANS_FN  \
# 0                       NaN               6745038.0                       NaN
# 1                       NaN                504500.0                       NaN
# 2                       NaN                897700.0                       NaN
# 3                       NaN               8042300.0                       NaN
# 4                       NaN               7998400.0                       NaN
#
#    VALU_OWND_FOLWNG_TRANS  VALU_OWND_FOLWNG_TRANS_FN  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#   DIRECT_INDIRECT_OWNERSHIP DIRECT_INDIRECT_OWNERSHIP_FN  \
# 0                         I                          NaN
# 1                         I                          NaN
# 2                         I                          NaN
# 3                         I                          NaN
# 4                         I                          NaN
#
#      NATURE_OF_OWNERSHIP NATURE_OF_OWNERSHIP_FN
# 0  By Shiraz Capital LLC                    NaN
# 1    By Havana 2020 GRAT                    NaN
# 2   By Elstead 2020 GRAT                    NaN
# 3  By Crescent River LLC                    NaN
# 4  By Crescent River LLC                    NaN

# %%
owner_signature = pd.read_csv('OWNER_SIGNATURE.tsv', sep='\t')
print(owner_signature.info())
owner_signature.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59339 entries, 0 to 59338
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ACCESSION_NUMBER    59339 non-null  object
#  1   OWNERSIGNATURENAME  59339 non-null  object
#  2   OWNERSIGNATUREDATE  59339 non-null  object
# dtypes: object(3)
# memory usage: 1.4+ MB
# None
#        ACCESSION_NUMBER                                 OWNERSIGNATURENAME  \
# 0  0000899243-23-016780  Brad Nelson as Attorney in Fact for Farhad Fre...
# 1  0001433195-23-000087  /s/ Matthew Mazza as Attorney-in-Fact for Andr...
# 2  0001433195-23-000086  /s/ Matthew Mazza, as Attorney-in-Fact for Win...
# 3  0001569187-23-000087  /s/ Louis S. Haddad, as Attorney-in-Fact for D...
# 4  0001433195-23-000085  /s/ Matthew S Mazza as Attorney-in-Fact for Ol...
#
#   OWNERSIGNATUREDATE
# 0        30-JUN-2023
# 1        30-JUN-2023
# 2        30-JUN-2023
# 3        30-JUN-2023
# 4        30-JUN-2023

# %%
owner_reporting = pd.read_csv('REPORTINGOWNER.tsv', sep='\t')
print(owner_reporting.info())
owner_reporting.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60049 entries, 0 to 60048
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ACCESSION_NUMBER       60049 non-null  object
#  1   RPTOWNERCIK            60049 non-null  int64
#  2   RPTOWNERNAME           60049 non-null  object
#  3   RPTOWNER_RELATIONSHIP  60043 non-null  object
#  4   RPTOWNER_TITLE         23616 non-null  object
#  5   RPTOWNER_TXT           1538 non-null   object
#  6   RPTOWNER_STREET1       59820 non-null  object
#  7   RPTOWNER_STREET2       35784 non-null  object
#  8   RPTOWNER_CITY          59993 non-null  object
#  9   RPTOWNER_STATE         59868 non-null  object
#  10  RPTOWNER_ZIPCODE       59764 non-null  object
#  11  RPTOWNER_STATE_DESC    2246 non-null   object
#  12  FILE_NUMBER            60049 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 6.0+ MB
# None
#        ACCESSION_NUMBER  RPTOWNERCIK           RPTOWNERNAME  \
# 0  0000899243-23-016780      1071351   EBRAHIMI FARHAD FRED
# 1  0001433195-23-000087      1643507  von Blottnitz Andreas
# 2  0001433195-23-000086      1439919   Webb Winifred Markus
# 3  0001569187-23-000087      1351710       Hoffler Daniel A
# 4  0001433195-23-000085      1801732       Nottebohm Olivia
#
#   RPTOWNER_RELATIONSHIP RPTOWNER_TITLE RPTOWNER_TXT  \
# 0       TenPercentOwner            NaN          NaN
# 1              Director            NaN          NaN
# 2              Director            NaN          NaN
# 3              Director            NaN          NaN
# 4              Director            NaN          NaN
#
#                       RPTOWNER_STREET1                     RPTOWNER_STREET2  \
# 0       191 UNIVERSITY BLVD, SUITE 246                                  NaN
# 1                   70 CASTILIAN DRIVE                                  NaN
# 2                   70 CASTILIAN DRIVE                                  NaN
# 3  C/O ARMADA HOFFLER PROPERTIES, INC.  222 CENTRAL PARK AVENUE, SUITE 2100
# 4                     70 CASTILIAN DR.                                  NaN
#
#     RPTOWNER_CITY RPTOWNER_STATE RPTOWNER_ZIPCODE RPTOWNER_STATE_DESC  \
# 0          DENVER             CO            80206                 NaN
# 1   SANTA BARBARA             CA            93117                 NaN
# 2   SANTA BARBARA             CA            93117                 NaN
# 3  VIRGINIA BEACH             VA            23462                 NaN
# 4   SANTA BARBARA             CA            93117                 NaN
#
#   FILE_NUMBER
# 0   001-37725
# 1   001-37468
# 2   001-37468
# 3   001-35908
# 4   001-37468

# %%
submissions = pd.read_csv('REPORTINGOWNER.tsv', sep='\t')
print(submissions.info())
submissions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60049 entries, 0 to 60048
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ACCESSION_NUMBER       60049 non-null  object
#  1   RPTOWNERCIK            60049 non-null  int64
#  2   RPTOWNERNAME           60049 non-null  object
#  3   RPTOWNER_RELATIONSHIP  60043 non-null  object
#  4   RPTOWNER_TITLE         23616 non-null  object
#  5   RPTOWNER_TXT           1538 non-null   object
#  6   RPTOWNER_STREET1       59820 non-null  object
#  7   RPTOWNER_STREET2       35784 non-null  object
#  8   RPTOWNER_CITY          59993 non-null  object
#  9   RPTOWNER_STATE         59868 non-null  object
#  10  RPTOWNER_ZIPCODE       59764 non-null  object
#  11  RPTOWNER_STATE_DESC    2246 non-null   object
#  12  FILE_NUMBER            60049 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 6.0+ MB
# None
#        ACCESSION_NUMBER  RPTOWNERCIK           RPTOWNERNAME  \
# 0  0000899243-23-016780      1071351   EBRAHIMI FARHAD FRED
# 1  0001433195-23-000087      1643507  von Blottnitz Andreas
# 2  0001433195-23-000086      1439919   Webb Winifred Markus
# 3  0001569187-23-000087      1351710       Hoffler Daniel A
# 4  0001433195-23-000085      1801732       Nottebohm Olivia
#
#   RPTOWNER_RELATIONSHIP RPTOWNER_TITLE RPTOWNER_TXT  \
# 0       TenPercentOwner            NaN          NaN
# 1              Director            NaN          NaN
# 2              Director            NaN          NaN
# 3              Director            NaN          NaN
# 4              Director            NaN          NaN
#
#                       RPTOWNER_STREET1                     RPTOWNER_STREET2  \
# 0       191 UNIVERSITY BLVD, SUITE 246                                  NaN
# 1                   70 CASTILIAN DRIVE                                  NaN
# 2                   70 CASTILIAN DRIVE                                  NaN
# 3  C/O ARMADA HOFFLER PROPERTIES, INC.  222 CENTRAL PARK AVENUE, SUITE 2100
# 4                     70 CASTILIAN DR.                                  NaN
#
#     RPTOWNER_CITY RPTOWNER_STATE RPTOWNER_ZIPCODE RPTOWNER_STATE_DESC  \
# 0          DENVER             CO            80206                 NaN
# 1   SANTA BARBARA             CA            93117                 NaN
# 2   SANTA BARBARA             CA            93117                 NaN
# 3  VIRGINIA BEACH             VA            23462                 NaN
# 4   SANTA BARBARA             CA            93117                 NaN
#
#   FILE_NUMBER
# 0   001-37725
# 1   001-37468
# 2   001-37468
# 3   001-35908
# 4   001-37468
